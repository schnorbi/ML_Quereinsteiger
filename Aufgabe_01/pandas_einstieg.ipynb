# %%
#pip install -U pandas numpy scikit-learn matplotlib seaborn torch torchvision

import pandas as pd
import pylab as pl

# %%
#Aufgabe 1:
df = pd.read_csv('housing.csv')
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#Aufgabe 2:
df['price'].mean()
# Out:
# 540088.1419053348

# %%
#Aufgabe 3:
df[df['bedrooms'] >= 3]
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000   221900         3       1.00         1180
# 1      6414100192  20141209T000000   538000         3       2.25         2570
# 3      2487200875  20141209T000000   604000         4       3.00         1960
# 4      1954400510  20150218T000000   510000         3       2.00         1680
# 5      7237550310  20140512T000000  1225000         4       4.50         5420
# ...           ...              ...      ...       ...        ...          ...
# 21606  7936000429  20150326T000000  1007500         4       3.50         3510
# 21607  2997800021  20150219T000000   475000         3       2.50         1310
# 21608   263000018  20140521T000000   360000         3       2.50         1530
# 21609  6600060120  20150223T000000   400000         4       2.50         2310
# 21611   291310100  20150116T000000   400000         3       2.50         1600
#
# ...

# %%
#Aufgabe 4:
df.groupby('bathrooms').size()
# Out:
# bathrooms
# 0.00      10
# 0.50       4
# 0.75      72
# 1.00    3852
# 1.25       9
# 1.50    1446
# 1.75    3048
# 2.00    1930
# 2.25    2047
# 2.50    5380
# 2.75    1185
# 3.00     753
# 3.25     589
# 3.50     731
# 3.75     155
# 4.00     136
# 4.25      79
# 4.50     100
# 4.75      23
# 5.00      21
# 5.25      13
# 5.50      10
# 5.75       4
# 6.00       6
# 6.25       2
# 6.50       2
# 6.75       2
# 7.50       1
# 7.75       1
# 8.00       2
# dtype: int64

# %%
#Aufgabe 5:
df.sort_values(by='yr_built', ascending=True)
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 4697   9126101645  20140610T000000  558000         4       2.00         2180
# 2961   1947300115  20140619T000000  464000         3       1.00         1320
# 12369  9138100350  20150218T000000  685000         4       2.00         2290
# 15016  1703400585  20141215T000000  325000         3       2.00         2330
# 5236    844000425  20141223T000000  199999         3       1.00          960
# ...           ...              ...     ...       ...        ...          ...
# 21270  1773100541  20150417T000000  389950         3       2.25         1580
# 17098  9126100346  20140617T000000  350000         3       2.00         1380
# 7526   9520900210  20141231T000000  614285         5       2.75         2730
# 20086  2768100512  20150422T000000  659000         2       2.50         1450
# 14489  2770601530  20140826T000000  500000         2       2.25         1570
#
# ...

# %%
#Aufgabe 6:
df['sqft_living'].hist(bins=200)
pl.title("Histogram of Wohnfläche")
pl.xlabel("Wohnfläche")
pl.ylabel("Anzahl")
# Out:
# Text(0, 0.5, 'Anzahl')

# %%
#Aufgabe 7:
df.pivot_table(values='price', index='floors', aggfunc='mean')
# Out:
#                price
# floors
# 1.0     4.421806e+05
# 1.5     5.589806e+05
# 2.0     6.488912e+05
# 2.5     1.060346e+06
# 3.0     5.825260e+05
# 3.5     9.333125e+05

# %%
#Aufgabe 8:
df[df['waterfront'] == 1].groupby('waterfront').size()
# Out:
# waterfront
# 1    163
# dtype: int64
